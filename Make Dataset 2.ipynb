# %%
def read_txt_file(file_path):
    """
    读取指定路径的JSON文件，并返回解析后的对象。
    
    :param file_path: JSON文件的路径
    :return: 解析后的JSON数据（通常为dict或list）
    """
    # 使用with语句打开文件，这样可以确保文件在使用完毕后正确关闭
    with open(file_path, 'r', encoding='utf-8') as file:
        # 使用read()方法读取文件的所有内容，并将它们存储在一个字符串变量中
        data = file.read()
    # print(type(data))
    # 此时，'data'变量包含了文件的所有内容。
    # 注意：如果文件是多行的，那么'data'中的内容也会包含换行符'\n'。
    return(data)

# %%
def write_txt_file(file_path, data):
    """
    将给定的数据写入到指定路径的JSON文件中。
    
    :param file_path: JSON文件的路径
    :param data: 要写入的数据（通常为dict或list）
    """
    with open(file_path, 'w', encoding='utf-8') as file:
        file.write(data)

# %%
import re
def extract_qa_pairs(text):
    """
    从给定的文本中提取问题和答案对，支持两种不同的格式，并去除开头和结尾的特定标记。
    
    参数:
    text (str): 包含问题和答案的文本。
    
    返回:
    list: 每个元素是一个包含问题和答案的子列表。
    """
    try:
        # 去除开始和结束标记之间的多余空格或换行符
        clean_text = text.split('<|begin_of_questions_and_answers|>\n')[1].split('<|end_of_questions_and_answers|>')[0]
    except IndexError:
        raise ValueError("The text does not contain the expected begin and end markers.")
    
    # 定义两种不同格式的正则表达式
    pattern_no_markdown = r'\d+\.\sQuestion:\s(.*?)\s+Answer:\s(.*?)(?=\n\d+\.|\Z)'
    pattern_markdown = r'\d+\.\s\*\*Question:\*\*\s(.*?)\s+\*\*Answer:\*\*\s(.*?)(?=\n\d+\.|\Z)'

    # 查找没有Markdown标记的问题和答案
    qa_pairs_no_md = re.findall(pattern_no_markdown, clean_text, re.DOTALL | re.MULTILINE)
    # 查找有Markdown标记的问题和答案，并去除Markdown标记
    qa_pairs_md = re.findall(pattern_markdown, clean_text, re.DOTALL | re.MULTILINE)
    qa_pairs_md_cleaned = [[q.replace("**", "").strip(), a.replace("**", "").strip()] for q, a in qa_pairs_md]

    # 合并结果
    qa_list = [[q.strip(), a.strip()] for q, a in qa_pairs_no_md] + qa_pairs_md_cleaned
    
    return qa_list

# %%
def deepseek_qa(txtfile, txtdir):
    file_path = f"{txtdir}\\{txtfile}"
    txt = read_txt_file(file_path)
    txt2 = read_txt_file(f"{qadir}\\{txtfile}")
    qa_list = extract_qa_pairs(txt2)
    
    count = 0
    print(f"{txtfile} is running")

    for qa in qa_list:
        count += 1
        reasoning_content = ""  # 定义完整思考过程
        answer_content = ""     # 定义完整回复
        is_answering = False   # 判断是否结束思考过程并开始回复
        # print(qa[0])
        # 创建聊天完成请求
        stream = client.chat.completions.create(
            model="qwen-turbo-latest",  # 此处以 deepseek-v3 为例，可按需更换模型名称
            messages=[
                {"role": "user", "content": f"""Based on a comprehensive review in the field of Metal-Organic Frameworks (MOFs) and related questions, generate a detailed and complete chain of scientific reasoning. Ensure that your reasoning process is rigorous and logically coherent, utilizing scientific theories and facts for analysis. The chain of reasoning can be open and flexible, not confined to a rigid structure, but it should clearly indicate the beginning and end of the reasoning.

Please use `<|begin_of_thought|>` to mark the start of the reasoning chain and `<|end_of_thought|>` to mark the end.

Don't mention "this literature show" or "this review show" or anything like that. This is very important. Even if you use the literature, your answer should still give the other person a style of thinking that is all about you.

The thought chain is as detailed as possible.
---

**Example Structure:**

1. **Understanding the Background:** Briefly explain the background information and main questions.
  
2. **Application of Knowledge:** Invoke relevant scientific principles and known facts related to the problem.
  
3. **Analysis Integration:** Integrate key information from the review into the analysis process.
  
4. **Reasoning Expansion:** Use logical reasoning to explore potential paths to a solution.
  
5. **Solution Evaluation:** Assess the plausibility and feasibility of different solutions.
  
6. **Conclusion Formation:** Draw clear scientific conclusions or hypotheses.
  
7. **Open Exploration:** Suggest possible future research directions or applications.
  

**Open Thought Chain Template:**

<|begin_of_thought|>

1. Preliminary Analysis: Clarify the subject and background information.
  
2. Theoretical Application: Identify and apply relevant scientific theories to support the analysis.
  
3. Logical Step-by-Step Reasoning: Gradually expand the reasoning, using review information to deepen the analysis.
  
4. Possibility Discussion: Explore potential conclusions and hypotheses, considering various scientific perspectives.
  
5. Result Summary: Summarize analysis results to form clear scientific conclusions.
  
6. Exploration Directions: Propose possible future research directions or application areas.
  

<|end_of_thought|>

Question:
{qa[0]}

Answer:
{qa[1]}

There is Artical:
{txt}"""}
        ],
        stream=True
        # 解除以下注释会在最后一个chunk返回Token使用量
        # stream_options={
        #     "include_usage": True
        # }
    )


        for chunk in stream:
            # 处理usage信息
            if not getattr(chunk, 'choices', None):
                print("\n" + "=" * 20 + "Token 使用情况" + "=" * 20 + "\n")
                print(chunk.usage)
                continue
    
            delta = chunk.choices[0].delta
    
            # 处理回复内容
            if getattr(delta, 'content', None):
                # print(delta.content, end='', flush=True)
                answer_content += delta.content
    
        # 如果需要打印完整内容，解除以下的注释
    
        # print("=" * 20 + "完整回复" + "=" * 20 + "\n")
        # print(answer_content)
        content = f"""<|begin_of_question|>\n\n{qa[0]}\n\n<|end_of_question|>\n\n<|begin_of_answer|>\n\n{qa[1]}\n\n<|end_of_answer|>\n\n{answer_content}"""
        
        write_txt_file(f"{file_path[:-4]}_{count}.txt", content)
        # print(f"file_path[:-4]_{count}.txt")
    return f"{txtfile} is done"

# %%
def main(txtdir):
    futures = []
    with ThreadPoolExecutor(max_workers=5) as executor:
        for txtfile in os.listdir(txtdir):
            if txtfile.endswith('.txt'):  # 确保只处理文本文件
                future = executor.submit(deepseek_qa, txtfile, txtdir)
                futures.append(future)
        
        # 收集结果
        for future in as_completed(futures):
            try:
                result = future.result()
                print(result)
            except Exception as e:
                print(f"生成了一个异常: {e}")

# %%
import os
from openai import OpenAI
from concurrent.futures import ThreadPoolExecutor, as_completed

client = OpenAI(
    # 若没有配置环境变量，请用百炼API Key将下行替换为：api_key="sk-xxx",
    api_key="", # 如何获取API Key：https://help.aliyun.com/zh/model-studio/developer-reference/get-api-key
    base_url="https://dashscope.aliyuncs.com/compatible-mode/v1",
)
qadir = "F:\\Working\\ModelDistillation\\qa"
txtdir = "F:\\Working\\ModelDistillation\\review"
main(txtdir)
# Out:
# 10.1002-advs.202203889.pdf.txt is running
# 10.1002-adma.202408416.pdf.txt is running
# 10.1002-adma.202412708.pdf.txt is running
# 10.1002-advs.202409290.pdf.txt is running
# 10.1002-advs.202304424.pdf.txt is running
# 10.1002-advs.202304424.pdf.txt is done
# 10.1002-aenm.202303281.pdf.txt is running
# 10.1002-adma.202412708.pdf.txt is done
# 10.1002-anie.202218076.pdf.txt is running
# 10.1002-advs.202409290.pdf.txt is done
# 10.1002-jssc.202201057.pdf.txt is running
# 10.1002-adma.202408416.pdf.txt is done
# 10.1002-marc.202300730.pdf.txt is running
# 10.1002-advs.202203889.pdf.txt is done
# 10.1002-smll.202301130.pdf.txt is running
# 10.1002-jssc.202201057.pdf.txt is done
# 10.1002-smll.202402783.pdf.txt is running
# 10.1002-aenm.202303281.pdf.txt is done
# 10.1002-smll.202404350.pdf.txt is running
# 10.1002-anie.202218076.pdf.txt is done
# 10.1007-s10653-024-01936-1.pdf.txt is running
# 10.1002-smll.202301130.pdf.txt is done
# 10.1007-s12274-023-5532-2.pdf.txt is running
# 10.1002-marc.202300730.pdf.txt is done
# 10.1007-s12274-023-5945-y.pdf.txt is running
# 10.1007-s12274-023-5532-2.pdf.txt is done
# 10.1007-s12274-023-6027-x.pdf.txt is running
# 10.1007-s10653-024-01936-1.pdf.txt is done
# 10.1007-s40820-023-01180-9.pdf.txt is running
# 10.1002-smll.202404350.pdf.txt is done
# 10.1007-s40820-024-01584-1.pdf.txt is running
# 10.1007-s12274-023-5945-y.pdf.txt is done
# 10.1007-s42773-024-00316-3.pdf.txt is running
# 10.1007-s12274-023-6027-x.pdf.txt is done
# 10.1016-j.carbpol.2024.122198.pdf.txt is running
# 10.1007-s40820-023-01180-9.pdf.txt is done
# 10.1016-j.ccr.2007.08.016.pdf.txt is running
# 10.1007-s40820-024-01584-1.pdf.txt is done
# 10.1016-j.ccr.2009.07.020.pdf.txt is running
# 10.1016-j.ccr.2007.08.016.pdf.txt is done
# 10.1016-j.ccr.2011.02.012.pdf.txt is running
# 10.1016-j.carbpol.2024.122198.pdf.txt is done
# 10.1016-j.ccr.2013.11.004.pdf.txt is running
# 10.1016-j.ccr.2009.07.020.pdf.txt is done
# 10.1016-j.ccr.2015.02.012.pdf.txt is running
# 生成了一个异常: Error code: 500 - {'error': {'code': 'internal_server_error', 'param': None, 'message': '<5000201> InternalError.Algo.ModelServingError.ModelServingWithDetailError: An error occurred in model serving with code: 500, and the error message is InternalError: Receive batching backend response failed!', 'type': 'internal_server_error'}, 'id': 'chatcmpl-7de6da3c-5e67-9f96-a139-76eb36da76ab', 'request_id': '7de6da3c-5e67-9f96-a139-76eb36da76ab'}
# 10.1016-j.ccr.2015.05.009.pdf.txt is running
# 10.1016-j.ccr.2011.02.012.pdf.txt is done
# 10.1016-j.ccr.2015.08.001.pdf.txt is running
# 10.1016-j.ccr.2015.02.012.pdf.txt is done
# 10.1016-j.ccr.2015.08.002.pdf.txt is running
# 10.1002-smll.202402783.pdf.txt is done
# 10.1016-j.ccr.2016.12.003.pdf.txt is running
# 10.1016-j.ccr.2015.05.009.pdf.txt is done
# 10.1016-j.ccr.2017.04.008.pdf.txt is running
# 10.1007-s42773-024-00316-3.pdf.txt is done
# 10.1016-j.ccr.2017.07.012.pdf.txt is running
# 10.1016-j.ccr.2017.07.012.pdf.txt is done
# 10.1016-j.ccr.2017.09.027.pdf.txt is running
# 10.1016-j.ccr.2015.08.002.pdf.txt is done
# 10.1016-j.ccr.2017.09.028.pdf.txt is running
# 10.1016-j.ccr.2015.08.001.pdf.txt is done
# 10.1016-j.ccr.2017.10.028.pdf.txt is running
# 10.1016-j.ccr.2017.04.008.pdf.txt is done
# 10.1016-j.ccr.2017.11.015.pdf.txt is running
# 10.1016-j.ccr.2016.12.003.pdf.txt is done
# 10.1016-j.ccr.2017.11.022.pdf.txt is running
# 10.1016-j.ccr.2017.09.028.pdf.txt is done
# 10.1016-j.ccr.2017.12.010.pdf.txt is running
# 10.1016-j.ccr.2017.09.027.pdf.txt is done
# 10.1016-j.ccr.2018.02.009.pdf.txt is running
# 10.1016-j.ccr.2017.11.015.pdf.txt is done
# 10.1016-j.ccr.2018.02.012.pdf.txt is running
# 10.1016-j.ccr.2017.10.028.pdf.txt is done
# 10.1016-j.ccr.2018.03.015.pdf.txt is running
# 10.1016-j.ccr.2017.12.010.pdf.txt is done
# 10.1016-j.ccr.2018.04.001.pdf.txt is running
# 10.1016-j.ccr.2017.11.022.pdf.txt is done
# 10.1016-j.ccr.2018.05.001.pdf.txt is running
# 10.1016-j.ccr.2018.03.015.pdf.txt is done
# 10.1016-j.ccr.2018.05.024.pdf.txt is running
# 10.1016-j.ccr.2018.05.024.pdf.txt is done
# 10.1016-j.ccr.2018.06.011.pdf.txt is running
# 10.1016-j.ccr.2018.02.012.pdf.txt is done
# 10.1016-j.ccr.2018.07.016.pdf.txt is running
# 10.1016-j.ccr.2018.05.001.pdf.txt is done
# 10.1016-j.ccr.2018.08.014.pdf.txt is running
# 10.1016-j.ccr.2018.06.011.pdf.txt is done
# 10.1016-j.ccr.2018.10.003.pdf.txt is running
# 10.1016-j.ccr.2018.07.016.pdf.txt is done
# 10.1016-j.ccr.2018.11.002.pdf.txt is running
# 10.1016-j.ccr.2018.02.009.pdf.txt is done
# 10.1016-j.ccr.2019.01.015.pdf.txt is running
# 10.1016-j.ccr.2018.08.014.pdf.txt is done
# 10.1016-j.ccr.2019.02.017.pdf.txt is running
# 10.1016-j.ccr.2018.11.002.pdf.txt is done
# 10.1016-j.ccr.2019.02.023.pdf.txt is running
# 10.1016-j.ccr.2018.04.001.pdf.txt is done
# 10.1016-j.ccr.2019.03.002.pdf.txt is running
# 10.1016-j.ccr.2019.01.015.pdf.txt is done
# 10.1016-j.ccr.2019.03.005.pdf.txt is running
# 10.1016-j.ccr.2019.02.017.pdf.txt is done
# 10.1016-j.ccr.2019.03.008.pdf.txt is running
# 10.1016-j.ccr.2019.03.002.pdf.txt is done
# 10.1016-j.ccr.2019.05.011.pdf.txt is running
# 10.1016-j.ccr.2019.02.023.pdf.txt is done
# 10.1016-j.ccr.2019.05.020.pdf.txt is running
# 10.1016-j.ccr.2019.05.011.pdf.txt is done
# 10.1016-j.ccr.2019.213025.pdf.txt is running
# 生成了一个异常: Error code: 500 - {'error': {'code': 'internal_server_error', 'param': None, 'message': '<5000201> InternalError.Algo.ModelServingError.ModelServingWithDetailError: An error occurred in model serving with code: 500, and the error message is InternalError: Receive batching backend response failed!', 'type': 'internal_server_error'}, 'id': 'chatcmpl-d0e9e013-7b11-9b13-b69f-71d9ca13b154', 'request_id': 'd0e9e013-7b11-9b13-b69f-71d9ca13b154'}
# 10.1016-j.ccr.2019.213100.pdf.txt is running
# 10.1016-j.ccr.2019.03.005.pdf.txt is done
# 10.1016-j.ccr.2019.213173.pdf.txt is running
# 10.1016-j.ccr.2019.03.008.pdf.txt is done
# 10.1016-j.ccr.2020.213191.pdf.txt is running
# 10.1016-j.ccr.2019.05.020.pdf.txt is done
# 10.1016-j.ccr.2020.213295.pdf.txt is running
# 10.1016-j.ccr.2019.213025.pdf.txt is done
# 10.1016-j.ccr.2020.213366.pdf.txt is running
# 10.1016-j.ccr.2019.213173.pdf.txt is done
# 10.1016-j.ccr.2020.213398.pdf.txt is running
# 10.1016-j.ccr.2019.213100.pdf.txt is done
# 10.1016-j.ccr.2020.213442.pdf.txt is running
# 10.1016-j.ccr.2020.213191.pdf.txt is done
# 10.1016-j.ccr.2020.213470.pdf.txt is running
# 10.1016-j.ccr.2020.213295.pdf.txt is done
# 10.1016-j.ccr.2020.213473.pdf.txt is running
# 10.1016-j.ccr.2020.213366.pdf.txt is done
# 10.1016-j.ccr.2020.213485.pdf.txt is running
# 10.1016-j.ccr.2020.213470.pdf.txt is done
# 10.1016-j.ccr.2020.213487.pdf.txt is running
# 10.1016-j.ccr.2020.213398.pdf.txt is done
# 10.1016-j.ccr.2020.213525.pdf.txt is running
# 10.1016-j.ccr.2020.213473.pdf.txt is done
# 10.1016-j.ccr.2020.213526.pdf.txt is running
# 10.1016-j.ccr.2020.213485.pdf.txt is done
# 10.1016-j.ccr.2020.213542.pdf.txt is running
# 10.1016-j.ccr.2020.213442.pdf.txt is done
# 生成了一个异常: The text does not contain the expected begin and end markers.
# 10.1016-j.ccr.2020.213565.pdf.txt is running
# 10.1016-j.ccr.2020.213487.pdf.txt is done
# 10.1016-j.ccr.2020.213583.pdf.txt is running
# 10.1016-j.ccr.2020.213525.pdf.txt is done
# 10.1016-j.ccr.2020.213665.pdf.txt is running
# 10.1016-j.ccr.2020.213526.pdf.txt is done
# 10.1016-j.ccr.2020.213679.pdf.txt is running
# 10.1016-j.ccr.2020.213565.pdf.txt is done
# 10.1016-j.ccr.2020.213709.pdf.txt is running
# 10.1016-j.ccr.2020.213583.pdf.txt is done
# 10.1016-j.ccr.2020.213735.pdf.txt is running
# 10.1016-j.ccr.2020.213542.pdf.txt is done
# 10.1016-j.ccr.2020.213738.pdf.txt is running
# 10.1016-j.ccr.2020.213679.pdf.txt is done
# 10.1016-j.ccr.2021.213780.pdf.txt is running
# 10.1016-j.ccr.2020.213665.pdf.txt is done
# 10.1016-j.ccr.2021.213786.pdf.txt is running
# 10.1016-j.ccr.2020.213735.pdf.txt is done
# 10.1016-j.ccr.2021.213827.pdf.txt is running
# 10.1016-j.ccr.2020.213709.pdf.txt is done
# 10.1016-j.ccr.2021.213852.pdf.txt is running
# 10.1016-j.ccr.2020.213738.pdf.txt is done
# 10.1016-j.ccr.2021.213861.pdf.txt is running
# 10.1016-j.ccr.2021.213786.pdf.txt is done
# 10.1016-j.ccr.2021.213862.pdf.txt is running
# 10.1016-j.ccr.2021.213780.pdf.txt is done
# 10.1016-j.ccr.2021.213892.pdf.txt is running
# 10.1016-j.ccr.2021.213892.pdf.txt is done
# 10.1016-j.ccr.2021.213902.pdf.txt is running
# 10.1016-j.ccr.2021.213902.pdf.txt is done
# 10.1016-j.ccr.2021.213924.pdf.txt is running
# 10.1016-j.ccr.2021.213852.pdf.txt is done
# 10.1016-j.ccr.2021.213948.pdf.txt is running
# 10.1016-j.ccr.2021.213861.pdf.txt is done
# 10.1016-j.ccr.2021.213955.pdf.txt is running
# 10.1016-j.ccr.2021.213862.pdf.txt is done
# 10.1016-j.ccr.2021.213968.pdf.txt is running
# 10.1016-j.ccr.2021.213924.pdf.txt is done
# 10.1016-j.ccr.2021.213970.pdf.txt is running
# 10.1016-j.ccr.2021.213948.pdf.txt is done
# 10.1016-j.ccr.2021.214020.pdf.txt is running
# 10.1016-j.ccr.2021.213955.pdf.txt is done
# 10.1016-j.ccr.2021.214034.pdf.txt is running
# 10.1016-j.ccr.2021.213970.pdf.txt is done
# 10.1016-j.ccr.2021.214037.pdf.txt is running
# 10.1016-j.ccr.2021.214034.pdf.txt is done
# 10.1016-j.ccr.2021.214050.pdf.txt is running
# 10.1016-j.ccr.2021.214020.pdf.txt is done
# 10.1016-j.ccr.2021.214060.pdf.txt is running
# 10.1016-j.ccr.2021.213827.pdf.txt is done
# 10.1016-j.ccr.2021.214072.pdf.txt is running
# 10.1016-j.ccr.2021.214037.pdf.txt is done
# 10.1016-j.ccr.2021.214125.pdf.txt is running
# 10.1016-j.ccr.2021.214060.pdf.txt is done
# 10.1016-j.ccr.2021.214148.pdf.txt is running
# 10.1016-j.ccr.2021.214072.pdf.txt is done
# 10.1016-j.ccr.2021.214234.pdf.txt is running
# 10.1016-j.ccr.2021.214148.pdf.txt is done
# 10.1016-j.ccr.2021.214237.pdf.txt is running
# 10.1016-j.ccr.2021.214050.pdf.txt is done
# 10.1016-j.ccr.2021.214241.pdf.txt is running
# 10.1016-j.ccr.2021.214241.pdf.txt is done
# 10.1016-j.ccr.2021.214245.pdf.txt is running
# 10.1016-j.ccr.2021.214237.pdf.txt is done
# 10.1016-j.ccr.2021.214262.pdf.txt is running
# 10.1016-j.ccr.2021.214245.pdf.txt is done
# 10.1016-j.ccr.2021.214263.pdf.txt is running
# 10.1016-j.ccr.2021.214234.pdf.txt is done
# 10.1016-j.ccr.2021.214301.pdf.txt is running
# 10.1016-j.ccr.2021.214125.pdf.txt is done
# 10.1016-j.ccr.2021.214314.pdf.txt is running
# 10.1016-j.ccr.2021.213968.pdf.txt is done
# 10.1016-j.ccr.2021.214332.pdf.txt is running
# 10.1016-j.ccr.2021.214332.pdf.txt is done
# 10.1016-j.ccr.2021.214364.pdf.txt is running
# 10.1016-j.ccr.2021.214262.pdf.txt is done
# 10.1016-j.ccr.2021.214376.pdf.txt is running
# 10.1016-j.ccr.2021.214364.pdf.txt is done
# 10.1016-j.ccr.2022.214428.pdf.txt is running
# 10.1016-j.ccr.2021.214301.pdf.txt is done
# 10.1016-j.ccr.2022.214445.pdf.txt is running
# 10.1016-j.ccr.2021.214314.pdf.txt is done
# 10.1016-j.ccr.2022.214521.pdf.txt is running
# 10.1016-j.ccr.2021.214376.pdf.txt is done
# 10.1016-j.ccr.2022.214539.pdf.txt is running
# 10.1016-j.ccr.2021.214263.pdf.txt is done
# 10.1016-j.ccr.2022.214558.pdf.txt is running
# 10.1016-j.ccr.2022.214428.pdf.txt is done
# 10.1016-j.ccr.2022.214562.pdf.txt is running
# 10.1016-j.ccr.2022.214539.pdf.txt is done
# 10.1016-j.ccr.2022.214595.pdf.txt is running
# 10.1016-j.ccr.2022.214558.pdf.txt is done
# 10.1016-j.ccr.2022.214598.pdf.txt is running
# 10.1016-j.ccr.2022.214521.pdf.txt is done
# 10.1016-j.ccr.2022.214628.pdf.txt is running
# 10.1016-j.ccr.2022.214628.pdf.txt is done
# 10.1016-j.ccr.2022.214629.pdf.txt is running
# 生成了一个异常: Error code: 400 - {'error': {'code': 'RequestTimeOut', 'param': None, 'message': 'RequestTimeOut', 'type': 'RequestTimeOut'}, 'id': 'chatcmpl-f1c62c7b-5b89-9072-8453-c69fc1acb708', 'request_id': 'f1c62c7b-5b89-9072-8453-c69fc1acb708'}
# 10.1016-j.ccr.2022.214645.pdf.txt is running
# 生成了一个异常: Error code: 500 - {'error': {'code': 'internal_server_error', 'param': None, 'message': '<5000201> InternalError.Algo.ModelServingError.ModelServingWithDetailError: An error occurred in model serving with code: 500, and the error message is InternalError: Receive batching backend response failed!', 'type': 'internal_server_error'}, 'id': 'chatcmpl-c6bb4a2b-752b-9b82-a19d-e4b89b03bdf6', 'request_id': 'c6bb4a2b-752b-9b82-a19d-e4b89b03bdf6'}
# 10.1016-j.ccr.2022.214670.pdf.txt is running
# 10.1016-j.ccr.2022.214629.pdf.txt is done
# 10.1016-j.ccr.2022.214714.pdf.txt is running
# 10.1016-j.ccr.2022.214595.pdf.txt is done
# 10.1016-j.ccr.2022.214759.pdf.txt is running
# 10.1016-j.ccr.2022.214645.pdf.txt is done
# 10.1016-j.ccr.2022.214776.pdf.txt is running
# 10.1016-j.ccr.2022.214670.pdf.txt is done
# 10.1016-j.ccr.2022.214796.pdf.txt is running
# 10.1016-j.ccr.2022.214759.pdf.txt is done
# 10.1016-j.ccr.2022.214815.pdf.txt is running
# 10.1016-j.ccr.2022.214776.pdf.txt is done
# 10.1016-j.ccr.2022.214868.pdf.txt is running
# 10.1016-j.ccr.2022.214714.pdf.txt is done
# 10.1016-j.ccr.2022.214876.pdf.txt is running
# 10.1016-j.ccr.2022.214815.pdf.txt is done
# 10.1016-j.ccr.2022.214877.pdf.txt is running
# 10.1016-j.ccr.2022.214796.pdf.txt is done
# 10.1016-j.ccr.2022.214912.pdf.txt is running
# 10.1016-j.ccr.2022.214868.pdf.txt is done
# 10.1016-j.ccr.2022.214917.pdf.txt is running
# 10.1016-j.ccr.2022.214562.pdf.txt is done
# 10.1016-j.ccr.2023.215043.pdf.txt is running
# 10.1016-j.ccr.2022.214876.pdf.txt is done
# 10.1016-j.ccr.2023.215093.pdf.txt is running
# 10.1016-j.ccr.2022.214912.pdf.txt is done
# 10.1016-j.ccr.2023.215101.pdf.txt is running
# 10.1016-j.ccr.2023.215043.pdf.txt is done
# 10.1016-j.ccr.2023.215111.pdf.txt is running
# 10.1016-j.ccr.2022.214877.pdf.txt is done
# 10.1016-j.ccr.2023.215112.pdf.txt is running
# 10.1016-j.ccr.2023.215093.pdf.txt is done
# 生成了一个异常: The text does not contain the expected begin and end markers.
# 10.1016-j.ccr.2023.215119.pdf.txt is running
# 10.1016-j.ccr.2022.214917.pdf.txt is done
# 10.1016-j.ccr.2023.215121.pdf.txt is running
# 10.1016-j.ccr.2023.215101.pdf.txt is done
# 10.1016-j.ccr.2023.215135.pdf.txt is running
# 10.1016-j.ccr.2023.215111.pdf.txt is done
# 10.1016-j.ccr.2023.215175.pdf.txt is running
# 10.1016-j.ccr.2023.215112.pdf.txt is done
# 10.1016-j.ccr.2023.215208.pdf.txt is running
# 10.1016-j.ccr.2023.215119.pdf.txt is done
# 10.1016-j.ccr.2023.215214.pdf.txt is running
# 10.1016-j.ccr.2023.215121.pdf.txt is done
# 10.1016-j.ccr.2023.215249.pdf.txt is running
# 10.1016-j.ccr.2023.215135.pdf.txt is done
# 10.1016-j.ccr.2023.215289.pdf.txt is running
# 10.1016-j.ccr.2023.215208.pdf.txt is done
# 10.1016-j.ccr.2023.215303.pdf.txt is running
# 10.1016-j.ccr.2023.215249.pdf.txt is done
# 10.1016-j.ccr.2023.215372.pdf.txt is running
# 10.1016-j.ccr.2023.215289.pdf.txt is done
# 10.1016-j.ccr.2023.215382.pdf.txt is running
# 10.1016-j.ccr.2023.215175.pdf.txt is done
# 10.1016-j.ccr.2023.215384.pdf.txt is running
# 10.1016-j.ccr.2023.215214.pdf.txt is done
# 10.1016-j.ccr.2023.215393.pdf.txt is running
# 10.1016-j.ccr.2023.215303.pdf.txt is done
# 10.1016-j.ccr.2023.215402.pdf.txt is running
# 10.1016-j.ccr.2023.215372.pdf.txt is done
# 10.1016-j.ccr.2023.215403.pdf.txt is running
# 10.1016-j.ccr.2023.215382.pdf.txt is done
# 10.1016-j.ccr.2023.215454.pdf.txt is running
# 10.1016-j.ccr.2023.215384.pdf.txt is done
# 10.1016-j.ccr.2023.215501.pdf.txt is running
# 10.1016-j.ccr.2023.215402.pdf.txt is done
# 10.1016-j.ccr.2023.215611.pdf.txt is running
# 10.1016-j.ccr.2023.215393.pdf.txt is done
# 10.1016-j.ccr.2024.215697.pdf.txt is running
# 10.1016-j.ccr.2023.215403.pdf.txt is done
# 10.1016-j.ccr.2024.215731.pdf.txt is running
# 10.1016-j.ccr.2023.215454.pdf.txt is done
# 10.1016-j.ccr.2024.215764.pdf.txt is running
# 10.1016-j.ccr.2023.215611.pdf.txt is done
# 10.1016-j.ccr.2024.215860.pdf.txt is running
# 10.1016-j.ccr.2024.215697.pdf.txt is done
# 10.1016-j.ccr.2024.215888.pdf.txt is running
# 10.1016-j.ccr.2024.215731.pdf.txt is done
# 10.1016-j.ccr.2024.215894.pdf.txt is running
# 10.1016-j.ccr.2024.215894.pdf.txt is done
# 10.1016-j.ccr.2024.215924.pdf.txt is running
# 10.1016-j.ccr.2024.215860.pdf.txt is done
# 10.1016-j.ccr.2024.215958.pdf.txt is running
# 10.1016-j.ccr.2024.215764.pdf.txt is done
# 10.1016-j.ccr.2024.215968.pdf.txt is running
# 10.1016-j.ccr.2024.215888.pdf.txt is done
# 10.1016-j.ccr.2024.215990.pdf.txt is running
# 10.1016-j.ccr.2023.215501.pdf.txt is done
# 10.1016-j.ccr.2024.215996.pdf.txt is running
# 10.1016-j.ccr.2024.215958.pdf.txt is done
# 10.1016-j.ccr.2024.216040.pdf.txt is running
# 10.1016-j.ccr.2024.215990.pdf.txt is done
# 10.1016-j.ccr.2024.216047.pdf.txt is running
# 10.1016-j.ccr.2024.215968.pdf.txt is done
# 10.1016-j.ccr.2024.216059.pdf.txt is running
# 10.1016-j.ccr.2024.216047.pdf.txt is done
# 10.1016-j.ccr.2024.216099.pdf.txt is running
# 10.1016-j.ccr.2024.215996.pdf.txt is done
# 10.1016-j.ccr.2024.216124.pdf.txt is running
# 10.1016-j.ccr.2024.216040.pdf.txt is done
# 10.1016-j.ccr.2024.216126.pdf.txt is running
# 10.1016-j.ccr.2024.215924.pdf.txt is done
# 10.1016-j.ccr.2024.216199.pdf.txt is running
# 10.1016-j.ccr.2024.216059.pdf.txt is done
# 10.1016-j.ccr.2024.216229.pdf.txt is running
# 10.1016-j.ccr.2024.216099.pdf.txt is done
# 10.1016-j.ccr.2024.216230.pdf.txt is running
# 10.1016-j.ccr.2024.216124.pdf.txt is done
# 10.1016-j.ccr.2024.216231.pdf.txt is running
# 10.1016-j.ccr.2024.216126.pdf.txt is done
# 10.1016-j.ccr.2024.216256.pdf.txt is running
# 10.1016-j.ccr.2024.216199.pdf.txt is done
# 10.1016-j.ccr.2024.216291.pdf.txt is running
# 10.1016-j.ccr.2024.216229.pdf.txt is done
# 10.1016-j.ccr.2024.216293.pdf.txt is running
# 10.1016-j.ccr.2024.216293.pdf.txt is done
# 10.1016-j.ccr.2024.216302.pdf.txt is running
# 10.1016-j.ccr.2024.216302.pdf.txt is done
# 10.1016-j.ccr.2024.216339.pdf.txt is running
# 10.1016-j.ccr.2024.216231.pdf.txt is done
# 10.1016-j.ccr.2024.216360.pdf.txt is running
# 10.1016-j.ccr.2024.216291.pdf.txt is done
# 10.1016-j.ccr.2024.216405.pdf.txt is running
# 10.1016-j.ccr.2024.216256.pdf.txt is done
# 10.1016-j.ccr.2025.216466.pdf.txt is running
# 10.1016-j.ccr.2024.216339.pdf.txt is done
# 10.1016-j.ccr.2025.216467.pdf.txt is running
# 10.1016-j.ccr.2024.216230.pdf.txt is done
# 10.1016-j.cej.2024.156241.pdf.txt is running
# 10.1016-j.ccr.2024.216360.pdf.txt is done
# 10.1016-j.chemosphere.2024.143194.pdf.txt is running
# 10.1016-j.ccr.2025.216466.pdf.txt is done
# 10.1016-j.dwt.2024.100437.pdf.txt is running
# 10.1016-j.ccr.2025.216467.pdf.txt is done
# 10.1016-j.gee.2022.12.010.pdf.txt is running
# 10.1016-j.cej.2024.156241.pdf.txt is done
# 10.1016-j.ijhydene.2023.04.029.pdf.txt is running
# 10.1016-j.chemosphere.2024.143194.pdf.txt is done
# 10.1016-j.ijhydene.2024.08.163.pdf.txt is running
# 10.1016-j.ijhydene.2024.08.163.pdf.txt is done
# 10.1016-j.jcou.2024.102727.pdf.txt is running
# 生成了一个异常: Error code: 400 - {'error': {'code': 'RequestTimeOut', 'param': None, 'message': 'RequestTimeOut', 'type': 'RequestTimeOut'}, 'id': 'chatcmpl-913108f2-2eaf-9553-a8e2-f301fc66e515', 'request_id': '913108f2-2eaf-9553-a8e2-f301fc66e515'}
# 10.1016-j.jece.2023.109291.pdf.txt is running
# 10.1016-j.dwt.2024.100437.pdf.txt is done
# 10.1016-j.jece.2023.109367.pdf.txt is running
# 10.1016-j.jcou.2024.102727.pdf.txt is done
# 10.1016-j.jece.2023.109469.pdf.txt is running
# 10.1016-j.ijhydene.2023.04.029.pdf.txt is done
# 10.1016-j.jece.2024.112964.pdf.txt is running
# 10.1016-j.ccr.2024.216405.pdf.txt is done
# 10.1016-j.jhazmat.2022.130127.pdf.txt is running
# 10.1016-j.jece.2023.109291.pdf.txt is done
# 10.1016-j.scitotenv.2023.165317.pdf.txt is running
# 10.1016-j.jece.2023.109469.pdf.txt is done
# 10.1016-j.scitotenv.2024.170085.pdf.txt is running
# 10.1016-j.scitotenv.2024.170085.pdf.txt is done
# 10.1016-j.scitotenv.2024.174501.pdf.txt is running
# 10.1016-j.jece.2023.109367.pdf.txt is done
# 10.1016-j.seppur.2023.123246.pdf.txt is running
# 10.1016-j.jhazmat.2022.130127.pdf.txt is done
# 10.1016-j.seppur.2024.127018.pdf.txt is running
# 10.1016-j.scitotenv.2023.165317.pdf.txt is done
# 10.1016-j.seppur.2024.127955.pdf.txt is running
# 10.1016-j.scitotenv.2024.174501.pdf.txt is done
# 10.1016-S1872-2067(23)64581-4.pdf.txt is running
# 10.1016-j.jece.2024.112964.pdf.txt is done
# 10.1021-acs.accounts.0c00582.pdf.txt is running
# 10.1016-j.seppur.2024.127955.pdf.txt is done
# 10.1021-acs.accounts.0c00695.pdf.txt is running
# 10.1021-acs.accounts.0c00582.pdf.txt is done
# 10.1021-acs.accounts.1c00029.pdf.txt is running
# 10.1021-acs.accounts.0c00695.pdf.txt is done
# 10.1021-acs.accounts.1c00280.pdf.txt is running
# 10.1021-acs.accounts.1c00280.pdf.txt is done
# 10.1021-acs.accounts.1c00328.pdf.txt is running
# 10.1016-S1872-2067(23)64581-4.pdf.txt is done
# 10.1021-acs.accounts.1c00377.pdf.txt is running
# 10.1021-acs.accounts.1c00029.pdf.txt is done
# 10.1021-acs.accounts.1c00555.pdf.txt is running
# 10.1021-acs.accounts.1c00328.pdf.txt is done
# 10.1021-acs.accounts.1c00600.pdf.txt is running
# 生成了一个异常: Error code: 400 - {'error': {'code': 'RequestTimeOut', 'param': None, 'message': 'RequestTimeOut', 'type': 'RequestTimeOut'}, 'id': 'chatcmpl-228ce5c4-f1c2-9a0e-a43a-f43c333f5510', 'request_id': '228ce5c4-f1c2-9a0e-a43a-f43c333f5510'}
# 10.1021-acs.accounts.1c00615.pdf.txt is running
# 10.1021-acs.accounts.1c00377.pdf.txt is done
# 10.1021-acs.accounts.2c00326.pdf.txt is running
# 10.1016-j.seppur.2023.123246.pdf.txt is done
# 10.1021-acs.accounts.2c00418.pdf.txt is running
# 10.1021-acs.accounts.1c00555.pdf.txt is done
# 10.1021-acs.accounts.5b00311.pdf.txt is running
# 10.1021-acs.accounts.1c00600.pdf.txt is done
# 10.1021-acs.accounts.5b00349.pdf.txt is running
# 10.1021-acs.accounts.1c00615.pdf.txt is done
# 10.1021-acs.accounts.6b00526.pdf.txt is running
# 10.1021-acs.accounts.2c00326.pdf.txt is done
# 10.1021-acs.accounts.6b00591.pdf.txt is running
# 10.1021-acs.accounts.5b00311.pdf.txt is done
# 10.1021-acs.accounts.7b00151.pdf.txt is running
# 10.1021-acs.accounts.2c00418.pdf.txt is done
# 10.1021-acs.accounts.7b00357.pdf.txt is running
# 10.1021-acs.accounts.5b00349.pdf.txt is done
# 10.1021-acs.accounts.8b00193.pdf.txt is running
# 10.1021-acs.accounts.6b00526.pdf.txt is done
# 10.1021-acs.accounts.8b00255.pdf.txt is running
# 10.1021-acs.accounts.6b00591.pdf.txt is done
# 10.1021-acs.accounts.8b00658.pdf.txt is running
# 10.1021-acs.accounts.7b00151.pdf.txt is done
# 10.1021-acs.accounts.9b00113.pdf.txt is running
# 10.1021-acs.accounts.7b00357.pdf.txt is done
# 10.1021-acs.accounts.9b00506.pdf.txt is running
# 10.1021-acs.accounts.8b00193.pdf.txt is done
# 生成了一个异常: The text does not contain the expected begin and end markers.
# 10.1021-acs.chemrev.0c00762.pdf.txt is running
# 10.1021-acs.accounts.8b00255.pdf.txt is done
# 10.1021-acs.chemrev.0c01029.pdf.txt is running
# 10.1021-acs.accounts.8b00658.pdf.txt is done
# 10.1021-acs.chemrev.2c00270.pdf.txt is running
# 10.1021-acs.accounts.9b00113.pdf.txt is done
# 10.1021-acs.chemrev.3c00248.pdf.txt is running
# 10.1021-acs.accounts.9b00506.pdf.txt is done
# 10.1021-acs.chemrev.3c00450.pdf.txt is running
# 生成了一个异常: Error code: 400 - {'error': {'code': 'RequestTimeOut', 'param': None, 'message': 'RequestTimeOut', 'type': 'RequestTimeOut'}, 'id': 'chatcmpl-c0c590fe-f0ff-925c-bc92-82b757a7e68e', 'request_id': 'c0c590fe-f0ff-925c-bc92-82b757a7e68e'}
# 10.1021-acs.chemrev.6b00173.pdf.txt is running
# 10.1021-acs.chemrev.3c00248.pdf.txt is done
# 10.1021-acs.chemrev.6b00346.pdf.txt is running
# 10.1021-acs.chemrev.0c01029.pdf.txt is done
# 10.1021-acs.chemrev.6b00626.pdf.txt is running
# 10.1021-acs.chemrev.2c00270.pdf.txt is done
# 10.1021-acs.chemrev.7b00091.pdf.txt is running
# 生成了一个异常: Error code: 400 - {'error': {'code': 'RequestTimeOut', 'param': None, 'message': 'RequestTimeOut', 'type': 'RequestTimeOut'}, 'id': 'chatcmpl-d1039e5a-1fc2-97c7-9a27-6df02c2fb8d2', 'request_id': 'd1039e5a-1fc2-97c7-9a27-6df02c2fb8d2'}
# 10.1021-acs.chemrev.9b00746.pdf.txt is running
# 10.1021-acs.chemrev.6b00173.pdf.txt is done
# 生成了一个异常: The text does not contain the expected begin and end markers.
# 10.1021-acs.chemrev.9b00797.pdf.txt is running
# 10.1021-acs.chemrev.6b00346.pdf.txt is done
# 10.1021-acs.chemrev.9b00803.pdf.txt is running
# 10.1021-acs.chemrev.7b00091.pdf.txt is done
# 10.1021-acs.chemrev.9b00828.pdf.txt is running
# 10.1021-acs.chemrev.3c00450.pdf.txt is done
# 10.1021-acs.chemrev.9b00842.pdf.txt is running
# 10.1021-acs.chemrev.9b00803.pdf.txt is done
# 10.1021-acs.jced.3c00778.pdf.txt is running
# 10.1021-acs.chemrev.9b00797.pdf.txt is done
# 10.1021-acsami.3c17503.pdf.txt is running
# 生成了一个异常: Output data may contain inappropriate content.
# 10.1021-acsorginorgau.3c00033.pdf.txt is running
# 10.1021-acs.chemrev.9b00828.pdf.txt is done
# 10.1021-ar100023y.pdf.txt is running
# 10.1021-acs.jced.3c00778.pdf.txt is done
# 10.1021-ar100112y.pdf.txt is running
# 10.1021-ar100023y.pdf.txt is done
# 10.1021-ar400151n.pdf.txt is running
# 10.1021-acsorginorgau.3c00033.pdf.txt is done
# 10.1021-jacs.0c06473.pdf.txt is running
# 10.1021-ar400151n.pdf.txt is done
# 10.1021-jacs.0c08773.pdf.txt is running
# 10.1021-ar100112y.pdf.txt is done
# 10.1021-jacs.0c10777.pdf.txt is running
# 10.1021-acs.chemrev.9b00842.pdf.txt is done
# 10.1021-jacs.4c12200.pdf.txt is running
# 10.1021-acs.chemrev.9b00746.pdf.txt is done
# 10.1021-jacs.5b10666.pdf.txt is running
# 10.1021-jacs.0c08773.pdf.txt is done
# 10.1021jacs.3c05425.pdf.txt is running
# 10.1021-jacs.0c10777.pdf.txt is done
# c1cs15055c.pdf.txt is running
# 10.1021-jacs.5b10666.pdf.txt is done
# c1cs15196g.pdf.txt is running
# 10.1021-jacs.4c12200.pdf.txt is done
# c1cs15221a.pdf.txt is running
# c1cs15221a.pdf.txt is done
# c4cs00230j.pdf.txt is running
# c1cs15055c.pdf.txt is done
# c5cs00307e.pdf.txt is running
# 10.1021jacs.3c05425.pdf.txt is done
# c5cs00837a.pdf.txt is running
# c1cs15196g.pdf.txt is done
# c6cs00362a.pdf.txt is running
# 10.1021-jacs.0c06473.pdf.txt is done
# c6cs00533k.pdf.txt is running
# c4cs00230j.pdf.txt is done
# c6cs00603e.pdf.txt is running
# c6cs00533k.pdf.txt is done
# c7cs00187h.pdf.txt is running
# c5cs00307e.pdf.txt is done
# c7cs00478h.pdf.txt is running
# c6cs00362a.pdf.txt is done
# c7cs00543a.pdf.txt is running
# c5cs00837a.pdf.txt is done
# c8cs00337h.pdf.txt is running
# c7cs00478h.pdf.txt is done
# c8cs00829a.pdf.txt is running
# c7cs00187h.pdf.txt is done
# c9cs00609e.pdf.txt is running
# c6cs00603e.pdf.txt is done
# chen-et-al-2023-analysis-and-refinement-of-host-guest-interactions-in-metal-organic-frameworks.pdf.txt is running
# chen-et-al-2023-analysis-and-refinement-of-host-guest-interactions-in-metal-organic-frameworks.pdf.txt is done
# d0cs00075b.pdf.txt is running
# c8cs00337h.pdf.txt is done
# d0cs00292e.pdf.txt is running
# c7cs00543a.pdf.txt is done
# d0cs00424c.pdf.txt is running
# c8cs00829a.pdf.txt is done
# d0cs00635a.pdf.txt is running
# c9cs00609e.pdf.txt is done
# d0cs00920b.pdf.txt is running
# d0cs00424c.pdf.txt is done
# d0cs00997k.pdf.txt is running
# d0cs00292e.pdf.txt is done
# d0cs01192d.pdf.txt is running
# d0cs00635a.pdf.txt is done
# d1cs00296a.pdf.txt is running
# d0cs01192d.pdf.txt is done
# d1cs00891a.pdf.txt is running
# d0cs00075b.pdf.txt is done
# d2cs00442a.pdf.txt is running
# d1cs00296a.pdf.txt is done
# d2cs01004f.pdf.txt is running
# d0cs00997k.pdf.txt is done
# d3cs00147d.pdf.txt is running
# d2cs01004f.pdf.txt is done
# d3cs00285c.pdf.txt is running
# d0cs00920b.pdf.txt is done
# d3cs00370a.pdf.txt is running
# d1cs00891a.pdf.txt is done
# d3cs00575e.pdf.txt is running
# 生成了一个异常: Error code: 400 - {'error': {'code': 'RequestTimeOut', 'param': None, 'message': 'RequestTimeOut', 'type': 'RequestTimeOut'}, 'id': 'chatcmpl-19b7363c-8af7-9a81-b775-45524c6c3d28', 'request_id': '19b7363c-8af7-9a81-b775-45524c6c3d28'}
# 生成了一个异常: The text does not contain the expected begin and end markers.
# d3cs00939d.pdf.txt is running
# d3cs00370a.pdf.txt is done
# d3ew00119a.pdf.txt is running
# d3cs00147d.pdf.txt is done
# d3mh00672g.pdf.txt is running
# d3cs00939d.pdf.txt is done
# d3qm00430a.pdf.txt is running
# d3cs00285c.pdf.txt is done
# d3sc06076d.pdf.txt is running
# d3ew00119a.pdf.txt is done
# d3ta07697k.pdf.txt is running
# d3qm00430a.pdf.txt is done
# d4cs00435c.pdf.txt is running
# d3sc06076d.pdf.txt is done
# d4cs00574k.pdf.txt is running
# d3ta07697k.pdf.txt is done
# d4cs00796d.pdf.txt is running
# d4cs00796d.pdf.txt is done
# fang-et-al-2024-advancing-electrically-conductive-metal-organic-frameworks-for-photocatalytic-energy-conversion.pdf.txt is running
# d3mh00672g.pdf.txt is done
# han-et-al-2024-sequential-linker-installation-in-metal-organic-frameworks.pdf.txt is running
# d4cs00435c.pdf.txt is done
# kim-et-al-2023-design-of-amine-containing-nanoporous-materials-for-postcombustion-co2-capture-from-engineering.pdf.txt is running
# fang-et-al-2024-advancing-electrically-conductive-metal-organic-frameworks-for-photocatalytic-energy-conversion.pdf.txt is done
# li-et-al-2023-ionic-liquids-functionalized-mofs-for-adsorption.pdf.txt is running
# han-et-al-2024-sequential-linker-installation-in-metal-organic-frameworks.pdf.txt is done
# li-et-al-2024-flexible-metal-organic-frameworks-from-local-structural-design-to-functional-realization.pdf.txt is running
# kim-et-al-2023-design-of-amine-containing-nanoporous-materials-for-postcombustion-co2-capture-from-engineering.pdf.txt is done
# qiu-et-al-2023-incorporating-catalytic-units-into-nanomaterials-rational-design-of-multipurpose-catalysts-for-co2.pdf.txt is running
# li-et-al-2024-flexible-metal-organic-frameworks-from-local-structural-design-to-functional-realization.pdf.txt is done
# rajendran-et-al-2023-how-can-(or-why-should)-process-engineering-aid-the-screening-and-discovery-of-solid-sorbents-for.pdf.txt is running
# qiu-et-al-2023-incorporating-catalytic-units-into-nanomaterials-rational-design-of-multipurpose-catalysts-for-co2.pdf.txt is done
# s10311-023-01589-z.pdf.txt is running
# rajendran-et-al-2023-how-can-(or-why-should)-process-engineering-aid-the-screening-and-discovery-of-solid-sorbents-for.pdf.txt is done
# su-et-al-2024-controlling-guest-diffusion-by-local-dynamic-motion-in-soft-porous-crystals-to-separate-water.pdf.txt is running
# d3cs00575e.pdf.txt is done
# vega-bahamon-2023-importance-of-bridging-molecular-and-process-modeling-to-design-optimal-adsorbents-for-large-scale.pdf.txt is running
# li-et-al-2023-ionic-liquids-functionalized-mofs-for-adsorption.pdf.txt is done
# wang-furukawa-2024-pore-networked-soft-materials-based-on-metal-organic-polyhedra.pdf.txt is running
# su-et-al-2024-controlling-guest-diffusion-by-local-dynamic-motion-in-soft-porous-crystals-to-separate-water.pdf.txt is done
# yamauchi-yanai-2024-toward-quantum-noses-quantum-chemosensing-based-on-molecular-qubits-in-metal-organic-frameworks.pdf.txt is running
# vega-bahamon-2023-importance-of-bridging-molecular-and-process-modeling-to-design-optimal-adsorbents-for-large-scale.pdf.txt is done
# zheng-et-al-2024-porous-metal-phosphonate-frameworks-construction-and-physical-properties.pdf.txt is running
# wang-furukawa-2024-pore-networked-soft-materials-based-on-metal-organic-polyhedra.pdf.txt is done
# s10311-023-01589-z.pdf.txt is done
# yamauchi-yanai-2024-toward-quantum-noses-quantum-chemosensing-based-on-molecular-qubits-in-metal-organic-frameworks.pdf.txt is done
# zheng-et-al-2024-porous-metal-phosphonate-frameworks-construction-and-physical-properties.pdf.txt is done
# d4cs00574k.pdf.txt is done
